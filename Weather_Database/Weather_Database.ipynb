# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 747

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
    
# Latitude and longitude
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
# Maximum temperature
        city_max_temp = city_weather["main"]["temp_max"]
# Humidity
        city_humidity = city_weather["main"]["humidity"]
# Cloudiness
        city_clouds = city_weather["clouds"]["all"]
# Wind speed
        city_wind = city_weather["wind"]["speed"]
# Country
        country = city_weather['sys']['country']
# Weather Description
        city_description = city_weather["weather"][0]["description"]
# Add the data to a list in a dictionary format and then convert the list to a DataFrame.
        city_data.append({
                "City": city.title(),
                "Lat": city_lat,
                "Lng": city_lng,
                "Max Temp": city_max_temp,
                "Cuurent Description": city_description,
                "Humidity": city_humidity,
                "Cloudiness": city_clouds,
                "Wind Speed": city_wind,
                "Country": country,
        })       
            
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | christchurch
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | van buren
# Processing Record 6 of Set 1 | amga
# Processing Record 7 of Set 1 | yeroham
# Processing Record 8 of Set 1 | eldikan
# City not found. Skipping...
# Processing Record 9 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 1 | axim
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | pacific grove
# Processing Record 19 of Set 1 | charters towers
# Processing Record 20 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 1 | dudinka
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | banda aceh
# Processing Record 24 of Set 1 | inhambane
# Processing Record 25 of Set 1 | brae
# Processing Record 26 of Set 1 | geraldton
# Processing Record 27 of Set 1 | lagos
# Processing Record 28 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 1 | souillac
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | ketchikan
# Processing Record 37 of Set 1 | vila velha
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | nosy varika
# Processing Record 40 of Set 1 | clyde river
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | hamilton
# Processing Record 43 of Set 1 | fomboni
# Processing Record 44 of Set 1 | westport
# Processing Record 45 of Set 1 | vila franca do campo
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | pecos
# Processing Record 48 of Set 1 | zalaszentgrot
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | hellvik
# Processing Record 2 of Set 2 | alice springs
# Processing Record 3 of Set 2 | sorbhog
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | altamont
# Processing Record 7 of Set 2 | yangambi
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | saint george
# Processing Record 11 of Set 2 | puteyets
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | luderitz
# Processing Record 16 of Set 2 | churumuco
# City not found. Skipping...
# Processing Record 17 of Set 2 | itarema
# Processing Record 18 of Set 2 | severo-kurilsk
# Processing Record 19 of Set 2 | comodoro rivadavia
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | diffa
# Processing Record 22 of Set 2 | manta
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | aswan
# Processing Record 25 of Set 2 | khingansk
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | soe
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | waipawa
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | hobyo
# Processing Record 33 of Set 2 | kolobrzeg
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | ukiah
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | margate
# Processing Record 38 of Set 2 | robertsport
# Processing Record 39 of Set 2 | guaruja
# Processing Record 40 of Set 2 | tommot
# Processing Record 41 of Set 2 | norman wells
# Processing Record 42 of Set 2 | huarmey
# Processing Record 43 of Set 2 | seddon
# Processing Record 44 of Set 2 | honningsvag
# Processing Record 45 of Set 2 | kichera
# Processing Record 46 of Set 2 | grand island
# Processing Record 47 of Set 2 | lebu
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | lavrentiya
# Processing Record 50 of Set 2 | nhulunbuy
# Processing Record 1 of Set 3 | tiksi
# Processing Record 2 of Set 3 | ancud
# Processing Record 3 of Set 3 | rikitea
# Processing Record 4 of Set 3 | klyuchi
# Processing Record 5 of Set 3 | talakan
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | provideniya
# Processing Record 8 of Set 3 | klaksvik
# Processing Record 9 of Set 3 | kaitangata
# Processing Record 10 of Set 3 | nichinan
# Processing Record 11 of Set 3 | tamandare
# Processing Record 12 of Set 3 | jiuquan
# Processing Record 13 of Set 3 | amahai
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | olavarria
# Processing Record 16 of Set 3 | esfarayen
# Processing Record 17 of Set 3 | namibe
# Processing Record 18 of Set 3 | senanga
# Processing Record 19 of Set 3 | petropavl
# Processing Record 20 of Set 3 | alenquer
# Processing Record 21 of Set 3 | victoria
# Processing Record 22 of Set 3 | khani
# Processing Record 23 of Set 3 | bredasdorp
# Processing Record 24 of Set 3 | touros
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | mastic beach
# Processing Record 27 of Set 3 | rojhan
# Processing Record 28 of Set 3 | nuuk
# Processing Record 29 of Set 3 | coquimbo
# Processing Record 30 of Set 3 | san cristobal
# Processing Record 31 of Set 3 | radis
# Processing Record 32 of Set 3 | talnakh
# Processing Record 33 of Set 3 | ostrovnoy
# Processing Record 34 of Set 3 | hofn
# Processing Record 35 of Set 3 | calamar
# Processing Record 36 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 3 | tucuman
# Processing Record 38 of Set 3 | pangody
# Processing Record 39 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 3 | beaupre
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | ishigaki
# Processing Record 43 of Set 3 | darnah
# Processing Record 44 of Set 3 | lady lake
# Processing Record 45 of Set 3 | dingle
# Processing Record 46 of Set 3 | kingman
# Processing Record 47 of Set 3 | oranjemund
# Processing Record 48 of Set 3 | fairbanks
# Processing Record 49 of Set 3 | derzhavinsk
# Processing Record 50 of Set 3 | cabra
# Processing Record 1 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 4 | haimen
# Processing Record 3 of Set 4 | chapais
# Processing Record 4 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 4 | deputatskiy
# Processing Record 6 of Set 4 | saldanha
# Processing Record 7 of Set 4 | tukrah
# Processing Record 8 of Set 4 | manokwari
# Processing Record 9 of Set 4 | hami
# Processing Record 10 of Set 4 | huntington
# Processing Record 11 of Set 4 | longyearbyen
# Processing Record 12 of Set 4 | morondava
# Processing Record 13 of Set 4 | kloulklubed
# Processing Record 14 of Set 4 | upernavik
# Processing Record 15 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 4 | eureka
# Processing Record 17 of Set 4 | katsuura
# Processing Record 18 of Set 4 | dwarka
# Processing Record 19 of Set 4 | salalah
# Processing Record 20 of Set 4 | alofi
# Processing Record 21 of Set 4 | englewood
# Processing Record 22 of Set 4 | san pedro
# Processing Record 23 of Set 4 | buenos aires
# Processing Record 24 of Set 4 | quatre cocos
# Processing Record 25 of Set 4 | aklavik
# Processing Record 26 of Set 4 | maxixe
# Processing Record 27 of Set 4 | fortuna
# Processing Record 28 of Set 4 | hasaki
# Processing Record 29 of Set 4 | moundou
# Processing Record 30 of Set 4 | cherskiy
# Processing Record 31 of Set 4 | regina
# Processing Record 32 of Set 4 | kropotkin
# Processing Record 33 of Set 4 | adrar
# Processing Record 34 of Set 4 | new norfolk
# Processing Record 35 of Set 4 | paamiut
# Processing Record 36 of Set 4 | nouadhibou
# Processing Record 37 of Set 4 | srednekolymsk
# Processing Record 38 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | sola
# Processing Record 40 of Set 4 | henties bay
# Processing Record 41 of Set 4 | la ronge
# Processing Record 42 of Set 4 | ahuimanu
# Processing Record 43 of Set 4 | west wendover
# Processing Record 44 of Set 4 | lae
# Processing Record 45 of Set 4 | sikasso
# Processing Record 46 of Set 4 | skjervoy
# Processing Record 47 of Set 4 | torbay
# Processing Record 48 of Set 4 | sao filipe
# Processing Record 49 of Set 4 | longview
# Processing Record 50 of Set 4 | fort nelson
# Processing Record 1 of Set 5 | russell
# Processing Record 2 of Set 5 | kavaratti
# Processing Record 3 of Set 5 | saint-ambroise
# Processing Record 4 of Set 5 | altay
# Processing Record 5 of Set 5 | sisimiut
# Processing Record 6 of Set 5 | sao gabriel da cachoeira
# Processing Record 7 of Set 5 | eenhana
# Processing Record 8 of Set 5 | sitka
# Processing Record 9 of Set 5 | matagami
# Processing Record 10 of Set 5 | caravelas
# Processing Record 11 of Set 5 | uruzgan
# Processing Record 12 of Set 5 | sugod
# Processing Record 13 of Set 5 | east london
# Processing Record 14 of Set 5 | tura
# Processing Record 15 of Set 5 | chokurdakh
# Processing Record 16 of Set 5 | sabla
# Processing Record 17 of Set 5 | danshui
# Processing Record 18 of Set 5 | intipuca
# Processing Record 19 of Set 5 | yaan
# Processing Record 20 of Set 5 | college
# Processing Record 21 of Set 5 | ixtapa
# Processing Record 22 of Set 5 | grand gaube
# Processing Record 23 of Set 5 | zwedru
# Processing Record 24 of Set 5 | qaqortoq
# Processing Record 25 of Set 5 | arraial do cabo
# Processing Record 26 of Set 5 | auki
# Processing Record 27 of Set 5 | faya
# Processing Record 28 of Set 5 | chuy
# Processing Record 29 of Set 5 | hay river
# Processing Record 30 of Set 5 | ashcroft
# Processing Record 31 of Set 5 | asau
# Processing Record 32 of Set 5 | vestmannaeyjar
# Processing Record 33 of Set 5 | ponta delgada
# Processing Record 34 of Set 5 | sechura
# Processing Record 35 of Set 5 | sri aman
# Processing Record 36 of Set 5 | dzheyrakh
# Processing Record 37 of Set 5 | bambanglipuro
# Processing Record 38 of Set 5 | inuvik
# Processing Record 39 of Set 5 | loa janan
# Processing Record 40 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 5 | mandera
# Processing Record 42 of Set 5 | malakal
# Processing Record 43 of Set 5 | maningrida
# Processing Record 44 of Set 5 | west fargo
# Processing Record 45 of Set 5 | vega de alatorre
# Processing Record 46 of Set 5 | dumas
# Processing Record 47 of Set 5 | erzin
# Processing Record 48 of Set 5 | rocha
# Processing Record 49 of Set 5 | mar del plata
# Processing Record 50 of Set 5 | tocopilla
# Processing Record 1 of Set 6 | cuenca
# Processing Record 2 of Set 6 | mabaruma
# Processing Record 3 of Set 6 | bethel
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 6 | booue
# Processing Record 7 of Set 6 | hailar
# Processing Record 8 of Set 6 | lata
# Processing Record 9 of Set 6 | ust-nera
# Processing Record 10 of Set 6 | yeppoon
# Processing Record 11 of Set 6 | esperance
# Processing Record 12 of Set 6 | tungi
# Processing Record 13 of Set 6 | alpena
# Processing Record 14 of Set 6 | berwick
# Processing Record 15 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 16 of Set 6 | gunjur
# Processing Record 17 of Set 6 | okhotsk
# Processing Record 18 of Set 6 | batticaloa
# Processing Record 19 of Set 6 | chincha alta
# Processing Record 20 of Set 6 | khatanga
# Processing Record 21 of Set 6 | makat
# Processing Record 22 of Set 6 | nanortalik
# Processing Record 23 of Set 6 | lalomanu
# City not found. Skipping...
# Processing Record 24 of Set 6 | rio gallegos
# Processing Record 25 of Set 6 | puerto quijarro
# Processing Record 26 of Set 6 | aranos
# Processing Record 27 of Set 6 | buala
# Processing Record 28 of Set 6 | boyolangu
# Processing Record 29 of Set 6 | kruisfontein
# Processing Record 30 of Set 6 | dunedin
# Processing Record 31 of Set 6 | zhuhai
# Processing Record 32 of Set 6 | leticia
# Processing Record 33 of Set 6 | north bend
# Processing Record 34 of Set 6 | westerland
# Processing Record 35 of Set 6 | luena
# Processing Record 36 of Set 6 | bengkulu
# Processing Record 37 of Set 6 | vardo
# Processing Record 38 of Set 6 | taveta
# Processing Record 39 of Set 6 | konevo
# Processing Record 40 of Set 6 | bolshaya vishera
# City not found. Skipping...
# Processing Record 41 of Set 6 | jadu
# Processing Record 42 of Set 6 | rawson
# Processing Record 43 of Set 6 | chapada dos guimaraes
# Processing Record 44 of Set 6 | neepawa
# Processing Record 45 of Set 6 | port hawkesbury
# Processing Record 46 of Set 6 | monte carmelo
# Processing Record 47 of Set 6 | vinh
# Processing Record 48 of Set 6 | songjianghe
# Processing Record 49 of Set 6 | ketchenery
# City not found. Skipping...
# Processing Record 50 of Set 6 | constitucion
# Processing Record 1 of Set 7 | comarapa
# Processing Record 2 of Set 7 | finspang
# Processing Record 3 of Set 7 | havre-saint-pierre
# Processing Record 4 of Set 7 | seoul
# Processing Record 5 of Set 7 | saint-joseph
# Processing Record 6 of Set 7 | nishihara
# Processing Record 7 of Set 7 | san jeronimo
# Processing Record 8 of Set 7 | luanda
# Processing Record 9 of Set 7 | nikolskoye
# Processing Record 10 of Set 7 | pekalongan
# Processing Record 11 of Set 7 | kralendijk
# Processing Record 12 of Set 7 | vanavara
# Processing Record 13 of Set 7 | iqaluit
# Processing Record 14 of Set 7 | marawi
# Processing Record 15 of Set 7 | labrea
# Processing Record 16 of Set 7 | shimoda
# Processing Record 17 of Set 7 | tazovskiy
# Processing Record 18 of Set 7 | ilo
# Processing Record 19 of Set 7 | xai-xai
# Processing Record 20 of Set 7 | port keats
# Processing Record 21 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 7 | puerto del rosario
# Processing Record 23 of Set 7 | synya
# Processing Record 24 of Set 7 | canutama
# Processing Record 25 of Set 7 | forestville
# Processing Record 26 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 7 | batemans bay
# Processing Record 28 of Set 7 | aquin
# Processing Record 29 of Set 7 | rumuruti
# Processing Record 30 of Set 7 | kirakira
# Processing Record 31 of Set 7 | campeche
# Processing Record 32 of Set 7 | prunisor
# Processing Record 33 of Set 7 | portland
# Processing Record 34 of Set 7 | necochea
# Processing Record 35 of Set 7 | fort wellington
# Processing Record 36 of Set 7 | port hardy
# Processing Record 37 of Set 7 | georgetown
# Processing Record 38 of Set 7 | uusikaupunki
# Processing Record 39 of Set 7 | sao joao da barra
# Processing Record 40 of Set 7 | xichang
# Processing Record 41 of Set 7 | arlit
# Processing Record 42 of Set 7 | saint-pierre
# Processing Record 43 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 7 | marienburg
# Processing Record 45 of Set 7 | mount gambier
# Processing Record 46 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 47 of Set 7 | khatra
# Processing Record 48 of Set 7 | namie
# Processing Record 49 of Set 7 | penzance
# Processing Record 50 of Set 7 | cachoeira do sul
# Processing Record 1 of Set 8 | veraval
# Processing Record 2 of Set 8 | bodden town
# Processing Record 3 of Set 8 | high rock
# Processing Record 4 of Set 8 | yulara
# Processing Record 5 of Set 8 | paucartambo
# City not found. Skipping...
# Processing Record 6 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 8 | japura
# Processing Record 8 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 8 | shkoder
# Processing Record 10 of Set 8 | jamtara
# Processing Record 11 of Set 8 | kozova
# Processing Record 12 of Set 8 | pevek
# Processing Record 13 of Set 8 | tasiilaq
# Processing Record 14 of Set 8 | paredon
# Processing Record 15 of Set 8 | la rochelle
# Processing Record 16 of Set 8 | dolinsk
# Processing Record 17 of Set 8 | te anau
# Processing Record 18 of Set 8 | broome
# Processing Record 19 of Set 8 | vilhena
# Processing Record 20 of Set 8 | dvinskoy
# Processing Record 21 of Set 8 | suntar
# Processing Record 22 of Set 8 | cockburn town
# Processing Record 23 of Set 8 | cayenne
# Processing Record 24 of Set 8 | bathsheba
# Processing Record 25 of Set 8 | labuhan
# Processing Record 26 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 8 | riacho de santana
# Processing Record 28 of Set 8 | solnechnyy
# Processing Record 29 of Set 8 | memphis
# Processing Record 30 of Set 8 | black diamond
# Processing Record 31 of Set 8 | isangel
# Processing Record 32 of Set 8 | ternate
# Processing Record 33 of Set 8 | palencia
# Processing Record 34 of Set 8 | pangoa
# Processing Record 35 of Set 8 | itoman
# Processing Record 36 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 8 | hongjiang
# Processing Record 38 of Set 8 | kungurtug
# Processing Record 39 of Set 8 | hirara
# Processing Record 40 of Set 8 | port macquarie
# Processing Record 41 of Set 8 | san isidro
# Processing Record 42 of Set 8 | jacareacanga
# Processing Record 43 of Set 8 | lexington park
# Processing Record 44 of Set 8 | yerbogachen
# Processing Record 45 of Set 8 | bajah
# Processing Record 46 of Set 8 | dicabisagan
# Processing Record 47 of Set 8 | lasa
# Processing Record 48 of Set 8 | guilin
# Processing Record 49 of Set 8 | saltillo
# Processing Record 50 of Set 8 | flin flon
# Processing Record 1 of Set 9 | borzya
# Processing Record 2 of Set 9 | roald
# Processing Record 3 of Set 9 | requena
# Processing Record 4 of Set 9 | lenggries
# Processing Record 5 of Set 9 | almaznyy
# Processing Record 6 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 9 | ubatuba
# Processing Record 8 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 9 of Set 9 | leshan
# Processing Record 10 of Set 9 | limon
# Processing Record 11 of Set 9 | camacha
# Processing Record 12 of Set 9 | ahipara
# Processing Record 13 of Set 9 | angoram
# Processing Record 14 of Set 9 | zyryanovsk
# Processing Record 15 of Set 9 | maturin
# Processing Record 16 of Set 9 | gao
# Processing Record 17 of Set 9 | sakakah
# Processing Record 18 of Set 9 | ekhabi
# Processing Record 19 of Set 9 | shima
# Processing Record 20 of Set 9 | mezhdurechenskiy
# Processing Record 21 of Set 9 | bilibino
# Processing Record 22 of Set 9 | nemencine
# Processing Record 23 of Set 9 | ellsworth
# Processing Record 24 of Set 9 | andapa
# Processing Record 25 of Set 9 | shaunavon
# Processing Record 26 of Set 9 | kribi
# Processing Record 27 of Set 9 | anjozorobe
# Processing Record 28 of Set 9 | saint-denis
# Processing Record 29 of Set 9 | kudahuvadhoo
# Processing Record 30 of Set 9 | washougal
# Processing Record 31 of Set 9 | ouango
# Processing Record 32 of Set 9 | mattru
# Processing Record 33 of Set 9 | mahebourg
# Processing Record 34 of Set 9 | kahului
# Processing Record 35 of Set 9 | lucenec
# Processing Record 36 of Set 9 | saint anthony
# Processing Record 37 of Set 9 | gat
# Processing Record 38 of Set 9 | faanui
# Processing Record 39 of Set 9 | kenai
# Processing Record 40 of Set 9 | zhanaozen
# Processing Record 41 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 9 | verkhoyansk
# Processing Record 43 of Set 9 | sladkovo
# Processing Record 44 of Set 9 | kamsack
# Processing Record 45 of Set 9 | pisco
# Processing Record 46 of Set 9 | husavik
# Processing Record 47 of Set 9 | kamina
# Processing Record 48 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 9 | northview
# Processing Record 50 of Set 9 | mangochi
# Processing Record 1 of Set 10 | rolla
# Processing Record 2 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 3 of Set 10 | novosokolniki
# Processing Record 4 of Set 10 | shizilu
# Processing Record 5 of Set 10 | george town
# Processing Record 6 of Set 10 | the valley
# Processing Record 7 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 8 of Set 10 | orange
# Processing Record 9 of Set 10 | camocim
# Processing Record 10 of Set 10 | maceio
# Processing Record 11 of Set 10 | san alberto
# Processing Record 12 of Set 10 | stabat
# Processing Record 13 of Set 10 | tautira
# Processing Record 14 of Set 10 | namatanai
# Processing Record 15 of Set 10 | merauke
# Processing Record 16 of Set 10 | strezhevoy
# Processing Record 17 of Set 10 | lorengau
# Processing Record 18 of Set 10 | saint-georges
# Processing Record 19 of Set 10 | roma
# Processing Record 20 of Set 10 | benghazi
# Processing Record 21 of Set 10 | mollendo
# Processing Record 22 of Set 10 | vanimo
# Processing Record 23 of Set 10 | bayan
# Processing Record 24 of Set 10 | tokur
# Processing Record 25 of Set 10 | creel
# Processing Record 26 of Set 10 | ambon
# Processing Record 27 of Set 10 | zhezkazgan
# Processing Record 28 of Set 10 | nome
# Processing Record 29 of Set 10 | cap malheureux
# Processing Record 30 of Set 10 | volot
# Processing Record 31 of Set 10 | rengo
# Processing Record 32 of Set 10 | muzquiz
# City not found. Skipping...
# Processing Record 33 of Set 10 | burica
# City not found. Skipping...
# Processing Record 34 of Set 10 | sidney
# Processing Record 35 of Set 10 | obluche
# City not found. Skipping...
# Processing Record 36 of Set 10 | nemuro
# Processing Record 37 of Set 10 | gimli
# Processing Record 38 of Set 10 | manggar
# Processing Record 39 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 10 | teknaf
# Processing Record 41 of Set 10 | flinders
# Processing Record 42 of Set 10 | sao felix do xingu
# Processing Record 43 of Set 10 | los llanos de aridane
# Processing Record 44 of Set 10 | berkovica
# Processing Record 45 of Set 10 | santiago
# Processing Record 46 of Set 10 | marquette
# Processing Record 47 of Set 10 | poya
# Processing Record 48 of Set 10 | punganuru
# Processing Record 49 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 50 of Set 10 | kailua
# Processing Record 1 of Set 11 | kavieng
# Processing Record 2 of Set 11 | emba
# Processing Record 3 of Set 11 | bereda
# Processing Record 4 of Set 11 | kashan
# Processing Record 5 of Set 11 | pasni
# Processing Record 6 of Set 11 | ilhabela
# Processing Record 7 of Set 11 | cabo san lucas
# Processing Record 8 of Set 11 | melo
# Processing Record 9 of Set 11 | olafsvik
# Processing Record 10 of Set 11 | leningradskiy
# Processing Record 11 of Set 11 | birin
# Processing Record 12 of Set 11 | lochem
# Processing Record 13 of Set 11 | kara-tyube
# Processing Record 14 of Set 11 | broken hill
# Processing Record 15 of Set 11 | marzuq
# Processing Record 16 of Set 11 | susanville
# Processing Record 17 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 11 | coahuayana
# Processing Record 19 of Set 11 | kamloops
# Processing Record 20 of Set 11 | macusani
# Processing Record 21 of Set 11 | leshukonskoye
# Processing Record 22 of Set 11 | buin
# Processing Record 23 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 11 | taoudenni
# Processing Record 25 of Set 11 | kashi
# Processing Record 26 of Set 11 | plettenberg bay
# Processing Record 27 of Set 11 | chazuta
# Processing Record 28 of Set 11 | manaquiri
# Processing Record 29 of Set 11 | melfi
# Processing Record 30 of Set 11 | karratha
# Processing Record 31 of Set 11 | tabarqah
# City not found. Skipping...
# Processing Record 32 of Set 11 | odweyne
# Processing Record 33 of Set 11 | kushima
# Processing Record 34 of Set 11 | kapit
# Processing Record 35 of Set 11 | feijo
# Processing Record 36 of Set 11 | valparaiso
# Processing Record 37 of Set 11 | lephepe
# City not found. Skipping...
# Processing Record 38 of Set 11 | port lincoln
# Processing Record 39 of Set 11 | glenwood springs
# Processing Record 40 of Set 11 | kununurra
# Processing Record 41 of Set 11 | inirida
# Processing Record 42 of Set 11 | camana
# Processing Record 43 of Set 11 | springville
# Processing Record 44 of Set 11 | srivardhan
# Processing Record 45 of Set 11 | laguna
# Processing Record 46 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 11 | pizhma
# Processing Record 48 of Set 11 | san andres
# Processing Record 49 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 11 | baghmara
# Processing Record 1 of Set 12 | beberibe
# Processing Record 2 of Set 12 | nkhotakota
# Processing Record 3 of Set 12 | biltine
# Processing Record 4 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 5 of Set 12 | livingston
# Processing Record 6 of Set 12 | gormi
# City not found. Skipping...
# Processing Record 7 of Set 12 | mushie
# Processing Record 8 of Set 12 | seguela
# Processing Record 9 of Set 12 | pavia
# Processing Record 10 of Set 12 | koutsouras
# Processing Record 11 of Set 12 | baiyin
# Processing Record 12 of Set 12 | aguie
# Processing Record 13 of Set 12 | beyneu
# Processing Record 14 of Set 12 | keningau
# Processing Record 15 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 16 of Set 12 | chase
# Processing Record 17 of Set 12 | ulaangom
# Processing Record 18 of Set 12 | praia da vitoria
# Processing Record 19 of Set 12 | murfreesboro
# Processing Record 20 of Set 12 | joshimath
# Processing Record 21 of Set 12 | shar
# Processing Record 22 of Set 12 | el dorado
# Processing Record 23 of Set 12 | cross lanes
# Processing Record 24 of Set 12 | mehamn
# Processing Record 25 of Set 12 | yar-sale
# Processing Record 26 of Set 12 | hamadan
# Processing Record 27 of Set 12 | wewak
# Processing Record 28 of Set 12 | bud
# Processing Record 29 of Set 12 | puerto escondido
# Processing Record 30 of Set 12 | matara
# Processing Record 31 of Set 12 | barahona
# Processing Record 32 of Set 12 | pangnirtung
# Processing Record 33 of Set 12 | nelson bay
# Processing Record 34 of Set 12 | dawlatabad
# Processing Record 35 of Set 12 | sur
# Processing Record 36 of Set 12 | monrovia
# Processing Record 37 of Set 12 | palmer
# Processing Record 38 of Set 12 | andenes
# Processing Record 39 of Set 12 | verkhnyaya inta
# Processing Record 40 of Set 12 | jining
# Processing Record 41 of Set 12 | teahupoo
# Processing Record 42 of Set 12 | xining
# Processing Record 43 of Set 12 | sirjan
# Processing Record 44 of Set 12 | udachnyy
# Processing Record 45 of Set 12 | sidi bu zayd
# City not found. Skipping...
# Processing Record 46 of Set 12 | ola
# Processing Record 47 of Set 12 | ozinki
# Processing Record 48 of Set 12 | hambantota
# Processing Record 49 of Set 12 | salinas
# Processing Record 50 of Set 12 | kondinskoye
# Processing Record 1 of Set 13 | santa marta
# Processing Record 2 of Set 13 | edmundston
# Processing Record 3 of Set 13 | shu
# Processing Record 4 of Set 13 | green river
# Processing Record 5 of Set 13 | tarnos
# Processing Record 6 of Set 13 | narsaq
# Processing Record 7 of Set 13 | gien
# Processing Record 8 of Set 13 | alibag
# Processing Record 9 of Set 13 | brazzaville
# Processing Record 10 of Set 13 | whitehorse
# Processing Record 11 of Set 13 | ihosy
# Processing Record 12 of Set 13 | acapulco
# Processing Record 13 of Set 13 | dongsheng
# Processing Record 14 of Set 13 | belogorsk
# Processing Record 15 of Set 13 | koslan
# Processing Record 16 of Set 13 | pucallpa
# Processing Record 17 of Set 13 | sergeyevka
# Processing Record 18 of Set 13 | anloga
# Processing Record 19 of Set 13 | balakhninskiy
# Processing Record 20 of Set 13 | bowen
# Processing Record 21 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 22 of Set 13 | kitgum
# Processing Record 23 of Set 13 | gra liyia
# Processing Record 24 of Set 13 | umm lajj
# Processing Record 25 of Set 13 | iberia
# Processing Record 26 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 13 | high level
# Processing Record 28 of Set 13 | dawei
# Processing Record 29 of Set 13 | abu kamal
# Processing Record 30 of Set 13 | bireun
# Processing Record 31 of Set 13 | bubaque
# Processing Record 32 of Set 13 | rio bonito
# Processing Record 33 of Set 13 | rock springs
# Processing Record 34 of Set 13 | birao
# Processing Record 35 of Set 13 | nizhneudinsk
# Processing Record 36 of Set 13 | minudasht
# Processing Record 37 of Set 13 | terrace bay
# Processing Record 38 of Set 13 | bac lieu
# Processing Record 39 of Set 13 | funadhoo
# Processing Record 40 of Set 13 | tabuk
# Processing Record 41 of Set 13 | grindavik
# Processing Record 42 of Set 13 | kendari
# Processing Record 43 of Set 13 | naya bazar
# Processing Record 44 of Set 13 | craig
# Processing Record 45 of Set 13 | liwale
# Processing Record 46 of Set 13 | hervey bay
# Processing Record 47 of Set 13 | notre-dame-du-lac
# Processing Record 48 of Set 13 | san jose
# Processing Record 49 of Set 13 | guangyuan
# Processing Record 50 of Set 13 | la palma
# Processing Record 1 of Set 14 | port shepstone
# Processing Record 2 of Set 14 | anadyr
# Processing Record 3 of Set 14 | leon
# Processing Record 4 of Set 14 | bandarbeyla
# Processing Record 5 of Set 14 | maunabo
# Processing Record 6 of Set 14 | redmond
# Processing Record 7 of Set 14 | puerto cortes
# City not found. Skipping...
# Processing Record 8 of Set 14 | teguldet
# Processing Record 9 of Set 14 | kampong cham
# Processing Record 10 of Set 14 | khovu-aksy
# Processing Record 11 of Set 14 | baculin
# Processing Record 12 of Set 14 | santo antonio do ica
# Processing Record 13 of Set 14 | barcelona
# Processing Record 14 of Set 14 | lyuban
# Processing Record 15 of Set 14 | mecca
# Processing Record 16 of Set 14 | hailey
# Processing Record 17 of Set 14 | ayer itam
# City not found. Skipping...
# Processing Record 18 of Set 14 | campbellsville
# Processing Record 19 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 20 of Set 14 | honjo
# Processing Record 21 of Set 14 | morlaix
# Processing Record 22 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 14 | ugoofaaru
# Processing Record 24 of Set 14 | sawai madhopur
# Processing Record 25 of Set 14 | araouane
# Processing Record 26 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 14 | samarai
# Processing Record 28 of Set 14 | kurilsk
# Processing Record 29 of Set 14 | nanga eboko
# Processing Record 30 of Set 14 | sinnar
# Processing Record 31 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 32 of Set 14 | honggang
# Processing Record 33 of Set 14 | avera
# Processing Record 34 of Set 14 | davila
# Processing Record 35 of Set 14 | taywarah
# Processing Record 36 of Set 14 | barabinsk
# Processing Record 37 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 14 | tanete
# Processing Record 39 of Set 14 | isfana
# Processing Record 40 of Set 14 | sabha
# Processing Record 41 of Set 14 | goundam
# Processing Record 42 of Set 14 | hitoyoshi
# Processing Record 43 of Set 14 | ostrov
# Processing Record 44 of Set 14 | saint-augustin
# Processing Record 45 of Set 14 | alyangula
# Processing Record 46 of Set 14 | misawa
# Processing Record 47 of Set 14 | diamantino
# Processing Record 48 of Set 14 | tomelloso
# Processing Record 49 of Set 14 | baturaja
# Processing Record 50 of Set 14 | puerto el triunfo
# Processing Record 1 of Set 15 | harper
# Processing Record 2 of Set 15 | kulhudhuffushi
# Processing Record 3 of Set 15 | brigantine
# Processing Record 4 of Set 15 | levelland
# Processing Record 5 of Set 15 | marfino
# Processing Record 6 of Set 15 | novolugovoye
# Processing Record 7 of Set 15 | port hedland
# Processing Record 8 of Set 15 | blythe
# Processing Record 9 of Set 15 | iroquois falls
# Processing Record 10 of Set 15 | slave lake
# Processing Record 11 of Set 15 | betsiamites
# Processing Record 12 of Set 15 | zyryanka
# Processing Record 13 of Set 15 | atar
# Processing Record 14 of Set 15 | igarape-miri
# City not found. Skipping...
# Processing Record 15 of Set 15 | miquelon
# Processing Record 16 of Set 15 | bonthe
# Processing Record 17 of Set 15 | elko
# Processing Record 18 of Set 15 | hlohovec
# Processing Record 19 of Set 15 | madinat sittah uktubar
# Processing Record 20 of Set 15 | jackson
# Processing Record 21 of Set 15 | clarence town
# Processing Record 22 of Set 15 | palembang
# Processing Record 23 of Set 15 | santa isabel do rio negro
# Processing Record 24 of Set 15 | brejo santo
# Processing Record 25 of Set 15 | cajuru
# Processing Record 26 of Set 15 | candolim
# Processing Record 27 of Set 15 | baherden
# Processing Record 28 of Set 15 | ambilobe
# Processing Record 29 of Set 15 | abay
# Processing Record 30 of Set 15 | yuanping
# Processing Record 31 of Set 15 | luba
# Processing Record 32 of Set 15 | misratah
# Processing Record 33 of Set 15 | ndele
# Processing Record 34 of Set 15 | liuzhou
# Processing Record 35 of Set 15 | vetrisoaia
# Processing Record 36 of Set 15 | san rafael
# Processing Record 37 of Set 15 | novosil
# Processing Record 38 of Set 15 | eganville
# Processing Record 39 of Set 15 | honiara
# Processing Record 40 of Set 15 | abu samrah
# Processing Record 41 of Set 15 | oranjestad
# Processing Record 42 of Set 15 | lagoa
# Processing Record 43 of Set 15 | maryborough
# Processing Record 44 of Set 15 | leeuwarden
# Processing Record 45 of Set 15 | catania
# Processing Record 46 of Set 15 | san quintin
# Processing Record 47 of Set 15 | qingyuan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Cuurent Description  Humidity  \
# 0    Christchurch -43.5333  172.6333     52.92     overcast clouds        79
# 1    Puerto Ayora  -0.7393  -90.3518     66.54    scattered clouds        87
# 2          Albany  42.6001  -73.9662     51.94     overcast clouds        94
# 3     Port Alfred -33.5906   26.8910     61.18       broken clouds        96
# 4       Van Buren  35.4368  -94.3483     50.02           clear sky        37
# 5            Amga  60.8953  131.9608     23.70     overcast clouds        79
# 6         Yeroham  30.9872   34.9314     65.08           clear sky        84
# 7            Axim   4.8699   -2.2405     75.97          few clouds        90
# 8  Ribeira Grande  38.5167  -28.7000     58.77       broken clouds        69
# 9          Avarua -21.2078 -159.7750     75.25          few clouds        69
#
#    Cloudiness  Wind Speed Country
# 0         100       24.16      NZ
# 1          49        1.01      EC
# 2         100        2.08      US
# 3          51        1.99      ZA
# 4           0        5.75      US
# 5         100        8.50      RU
# 6           2        2.93      IL
# 7          15        3.38      GH
# 8          79        5.99      PT
# 9          20       12.66      CK

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Cuurent Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
reorganize_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Cuurent Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[reorganize_columns]

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Christchurch      NZ -43.5333  172.6333     52.92        79         100
# 1  Puerto Ayora      EC  -0.7393  -90.3518     66.54        87          49
# 2        Albany      US  42.6001  -73.9662     51.94        94         100
# 3   Port Alfred      ZA -33.5906   26.8910     61.18        96          51
# 4     Van Buren      US  35.4368  -94.3483     50.02        37           0
#
#    Wind Speed Cuurent Description
# 0       24.16     overcast clouds
# 1        1.01    scattered clouds
# 2        2.08     overcast clouds
# 3        1.99       broken clouds
# 4        5.75           clear sky

# %%
# Fix my spelling error... 

city_data_df.rename(columns = {'Cuurent Description':'Current Description'}, inplace = True)

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file)
